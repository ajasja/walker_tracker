# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import matplotlib.pyplot as plt
plt.rcParams['figure.dpi'] = 150

import numpy as np
import picasso

# %%
import os
os.environ['HDF5_DISABLE_VERSION_CHECK']='1'
from picasso import localize
# Out:
# C:\bin\python\anaconda64\envs\picasso\lib\site-packages\h5py\__init__.py:37: UserWarning: h5py is running against HDF5 1.10.5 when it was built against 1.10.6, this may cause problems
#   _warn(("h5py is running against HDF5 {0} when it was built against {1}, "

# %%
localize.fit()

# %%
io.
