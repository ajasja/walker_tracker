# %%
from pathlib import Path
import glob
import papermill as pm


in_folder = r"C:\tmp"
out_folder = r"C:\tmp\corrected"
path_to_notebook='01-fit-one-trajectory.ipynb' 


in_folder = Path(in_folder)
tiff_filelist = glob.glob(f"{in_folder}/*.tiff")
for file in tiff_filelist:
    print(file)
    pm.execute_notebook(
            "01-fit-one-trajectory.ipynb",
            "temp_fit_notebook.ipynb",
            parameters=dict(in_path=directory, in_filename=file, out_path="out"),
        )
# Out:
# C:/tmp/20240430-121417_WT.tiff
# C:/bin/Fiji.app/ImageJ-win64.exe -macro "C:/tmp/corrected/20240430-121417_WT_temp_macro.ijm"
# Begin fiji processing
# Finished fiji processing
# c:\bin\conda\envs\pyimage\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# c:\bin\conda\envs\pyimage\lib\site-packages\numpy\.libs\libopenblas64__v0.3.21-gcc_10_3_0.dll
# c:\bin\conda\envs\pyimage\lib\site-packages\numpy\.libs\libopenblas64__v0.3.23-246-g3d31191b-gcc_10_3_0.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"
