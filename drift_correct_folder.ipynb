# %%
import os
from pathlib import Path
import glob

in_folder = r"L:\CC-WALK\TIRF\walkers\30042024_1a8_2d7_1nM"
out_folder = r"C:\tmp\corrected"
#I couldn't get fiji to be detected. For now this is a way to make it work. Just point it to your fiji
path_to_fiji='C:/"Program Files"/Fiji.app/ImageJ-win64.exe' 
path_to_fiji='C:/bin/Fiji.app/ImageJ-win64.exe' 


in_folder = Path(in_folder)
tiff_filelist = glob.glob(f"{in_folder}/20240430-124835_WT_aligned.tiff")
for file in tiff_filelist:
    file=file.replace("\\","/")
    print(file)
    # !python drift_correction_fiji.py {file} -f {path_to_fiji} -o {out_folder} --dry-run
