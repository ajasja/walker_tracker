# %%
from pathlib import Path
import glob

in_folder = "data/05022024_1a8_2b11_0.5nM"
out_folder = "data/05022024_1a8_2b11_0.5nM/out"
#I couldn't get fiji to be detected. For now this is a way to make it work. Just point it to your fiji
path_to_fiji='C:/"Program Files"/Fiji.app/ImageJ-win64.exe' 
#path_to_fiji='C:/bin/Fiji.app/ImageJ-win64.exe' 


in_folder = Path(in_folder)
tiff_filelist = glob.glob(f"{in_folder}/*.tiff")
for file in tiff_filelist:
    file=file.replace("\\","/")
    print(file)
    # !python drift_correction_fiji.py {file} -f {path_to_fiji} -o {out_folder}
# Out:
# data/05022024_1a8_2b11_0.5nM/20240205-133456_WT.tiff
# data/05022024_1a8_2b11_0.5nM/20240205-134328_WT.tiff
# Traceback (most recent call last):
#   File "c:\Kemijski_Institut\Code\walker_tracker\drift_correction_fiji.py", line 3, in <module>
#     import lumicks.pylake as lk
# ModuleNotFoundError: No module named 'lumicks'
# data/05022024_1a8_2b11_0.5nM/20240205-135106_WT.tiff
# Traceback (most recent call last):
#   File "c:\Kemijski_Institut\Code\walker_tracker\drift_correction_fiji.py", line 3, in <module>
#     import lumicks.pylake as lk
# ModuleNotFoundError: No module named 'lumicks'
# data/05022024_1a8_2b11_0.5nM/20240205-135429_WT.tiff
# Traceback (most recent call last):
#   File "c:\Kemijski_Institut\Code\walker_tracker\drift_correction_fiji.py", line 3, in <module>
#     import lumicks.pylake as lk
# ModuleNotFoundError: No module named 'lumicks'
# data/05022024_1a8_2b11_0.5nM/20240205-141407_WT_dober.tiff
# Traceback (most recent call last):
#   File "c:\Kemijski_Institut\Code\walker_tracker\drift_correction_fiji.py", line 3, in <module>
#     import lumicks.pylake as lk
# ModuleNotFoundError: No module named 'lumicks'
# data/05022024_1a8_2b11_0.5nM/20240205-143936_WT.tiff
# Traceback (most recent call last):
#   File "c:\Kemijski_Institut\Code\walker_tracker\drift_correction_fiji.py", line 3, in <module>
#     import lumicks.pylake as lk
# ModuleNotFoundError: No module named 'lumicks'
# data/05022024_1a8_2b11_0.5nM/20240205-145635_WT.tiff
# Traceback (most recent call last):
#   File "c:\Kemijski_Institut\Code\walker_tracker\drift_correction_fiji.py", line 3, in <module>
#     import lumicks.pylake as lk
# ModuleNotFoundError: No module named 'lumicks'
# data/05022024_1a8_2b11_0.5nM/20240205-151222_WT.tiff
# Traceback (most recent call last):
#   File "c:\Kemijski_Institut\Code\walker_tracker\drift_correction_fiji.py", line 3, in <module>
#     import lumicks.pylake as lk
# ModuleNotFoundError: No module named 'lumicks'
# data/05022024_1a8_2b11_0.5nM/20240205-152857_WT.tiff
# Traceback (most recent call last):
#   File "c:\Kemijski_Institut\Code\walker_tracker\drift_correction_fiji.py", line 3, in <module>
#     import lumicks.pylake as lk
# ModuleNotFoundError: No module named 'lumicks'
# Traceback (most recent call last):
#   File "c:\Kemijski_Institut\Code\walker_tracker\drift_correction_fiji.py", line 3, in <module>
#     import lumicks.pylake as lk
# ModuleNotFoundError: No module named 'lumicks'
