# %%
import os
from pathlib import Path
import glob

folder = "data"

#I couldn't get fiji to be detected. For now this is a way to make it work. Just point it to your fiji
path_to_fiji='C:/"Program Files"/Fiji.app/ImageJ-win64.exe' 

tiff_filelist = glob.glob(f"{folder}/*.tiff")
for file in tiff_filelist:
    file=file.replace("\\","/")
    print(file)
    output_path = (os.path.join(folder, Path(file).stem + "_output/")).replace("\\","/")
    # !python drift_correction_fiji.py {file} -f {path_to_fiji} -o {output_path}
# Out:
# data/20240112-113918_WT_0.5nM_15min_po_dodatku_LT_1.tiff
# Begin fiji processing
# Finished fiji processing
# data/20240112-114721_WT_0.5nM_20min_po_dodatku_LT_N.tiff
# Traceback (most recent call last):
#   File "c:\Users\feder\OneDrive\Documents\Slovenija\Kemijski_Institut\Code\walker_tracker\drift_correction_fiji.py", line 118, in <module>
#     os.remove("{}/outputDriftTable.njt".format(output_path))
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'data\\20240112-113918_WT_0.5nM_15min_po_dodatku_LT_1_output///outputDriftTable.njt'
