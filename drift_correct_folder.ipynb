# %%
import os
from pathlib import Path
import glob

in_folder = "./data"
out_folder = "./data/out"
#I couldn't get fiji to be detected. For now this is a way to make it work. Just point it to your fiji
path_to_fiji='C:/"Program Files"/Fiji.app/ImageJ-win64.exe' 
path_to_fiji='C:/bin/Fiji.app/ImageJ-win64.exe' 


in_folder = Path(in_folder)
tiff_filelist = glob.glob(f"{in_folder}/*.tiff")
for file in tiff_filelist:
    file=file.replace("\\","/")
    print(file)
    # !python drift_correction_fiji.py {file} -f {path_to_fiji} -o {out_folder}
# Out:
# data/20240112-113918_WT_0.5nM_15min_po_dodatku_LT_1.tiff
# Begin fiji processingdata/20240112-114721_WT_0.5nM_20min po dodatku_LT_N.tiff
#
# Finished fiji processing
# data/20240112-115546_WT_0.5nM_40min po dodatku_LT_1.tiff
# usage: drift_correction_fiji.py [-h] [-o OUTPUT_DIRECTORY] [-f PATH_TO_FIJI]
#                                 [--keep_uncorrected_movie KEEP_UNCORRECTED_MOVIE]
#                                 movie_file
# drift_correction_fiji.py: error: unrecognized arguments: po dodatku_LT_N.tiff
# data/20240112-122600_WT_1.tiff
# usage: drift_correction_fiji.py [-h] [-o OUTPUT_DIRECTORY] [-f PATH_TO_FIJI]
#                                 [--keep_uncorrected_movie KEEP_UNCORRECTED_MOVIE]
#                                 movie_file
# drift_correction_fiji.py: error: unrecognized arguments: po dodatku_LT_1.tiff
# Begin fiji processingdata/20240112-124154_WT_1.tiff
#
# Finished fiji processing
# Begin fiji processing
# Finished fiji processing
# data/20240112-125040_WT.tiff
# Begin fiji processing
# Finished fiji processing
