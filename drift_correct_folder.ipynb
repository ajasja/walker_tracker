# %%
from pathlib import Path
import glob

in_folder = r"C:\Users\lizau\Desktop\walker_tracker_for_article\walker_tracker\example\undrifting"
out_folder = r"C:\Users\lizau\Desktop\walker_tracker_for_article\walker_tracker\tracker\example\undrifting\out"

#I couldn't get fiji to be detected. For now this is a way to make it work. Just point it to your fiji
#path_to_fiji='C:/"Program Files"/Fiji.app/ImageJ-win64.exe' 
path_to_fiji= r"C:\Users\lizau\fiji-win64\Fiji.app\ImageJ-win64.exe" 

in_folder = Path(in_folder)
tiff_filelist = glob.glob(f"{in_folder}/*.tif")
for file in tiff_filelist:
    file=file.replace("\\","/")
    print(file)
    # !python drift_correction_fiji.py {file} -f {path_to_fiji} -o {out_folder}
